# %% [markdown]
# # Database construction on Sqlite3

# %% [markdown]
# Firstly, we need to save all the needed PMIDs from PubMed, which can be easily done by clicking "save" button on PubMed and filter the results.

# %% [markdown]
# An example of the saved text file

# %%
path = 'pmid-HeartTrans_mortality-set.txt'
with open(path,'r',encoding='utf-8') as f:
    pmid_HtM = f.read()
pmid_HtM_list = pmid_HtM.split("\n")
pmid_HtM_list[0]
# Out:
# '28413189'

# %% [markdown]
# Insert all the articles into the table

# %%
## Run once only
import gzip
import json
import time
import sqlite3

def jsonlreader(path):
    for line in gzip.open(path, "rt"):
        yield json.loads(line)

conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')        
cu = conn.cursor()
## create table
# cu.execute('''create table if not exists articles(
#         pmid TEXT,
#         title TEXT,
#         abstract TEXT,
#         mesh TEXT,
#         keywords TEXT,
#         pubyear INTEGER)''')

i = 0
articles_list = []
start = time.time()
for article in jsonlreader("D:\\pubmed22.jsonl.gz"):
    articles_list.append((article["PMID"],article["Title"],str(article["Abstract"]),str(article["MeSH"])\
                          ,str(article["Keywords"]),article["PubDate"]["Year"]))
    i += 1
    if i % 500000 == 0 or i == 33405863:
        cu.executemany('INSERT INTO articles VALUES (?,?,?,?,?,?);',articles_list)
        articles_list = []
        print('We have inserted', cu.rowcount, 'articles to the table.') 
end = time.time()
print("Time cost:",end - start)
conn.commit()
conn.close()
# Out:
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 500000 articles to the table.
# We have inserted 405863 articles to the table.
# Time cost: 2775.55694937706

# %% [markdown]
# Add index to the table to make it searching faster

# %%
## Run once only
## create index for pmid 
start = time.time()
conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')
c = conn.cursor()
c.execute("CREATE INDEX pmid_index ON articles(pmid);") # create index
# c.execute("DROP INDEX pmid_index;") # delete index
# c.execute("DELETE from articles;") # delete table
conn.commit()
conn.close()
end = time.time()
print("Time cost:",end - start)
# Out:
# Time cost: 405.51740169525146

# %% [markdown]
# ### Construct the positive dataset

# %%
import time
import sqlite3
import ast
import os

# %% [markdown]
# Check if there are duplicated PMIDs in the saved text file

# %%
## Positive pmid
path = "pmid-HeartTrans_Mortality-set.txt"
with open(path,'r',encoding='utf-8') as f:
    text = f.read()
positive = text.split("\n")
p = set(positive)
if len(positive) == len(p):
    print("No duplicated PMID in the list.")
else:
    le = len(positive) - len(p)
    print("%d duplicated PMIDs in the list have been removed, and the order in the list was not changed." % le)
    new_list = list(p)
    new_list.sort(key=positive.index)
    positive = new_list
# Out:
# No duplicated PMID in the list.

# %% [markdown]
# Check if the corresponding articles have "Mortality"

# %%
## Test positive data
conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')
cu = conn.cursor()
statement = "SELECT * from articles  WHERE pmid in ({0})".format(', '.join(['?'] * len(positive)))
article = cu.execute(statement, positive)
i = 0
for row in article:
    s = ""
    pmid = row[0]
    title = row[1]
    abstact = row[2]
    mesh = row[3]
    keywords = row[4]
    mesh_list = ast.literal_eval(mesh)
    key = 0
    for term in mesh_list:
        if term["Name"] in ["Heart Transplantation","Heart-Lung Transplantation"]:
            for qual in term["Qualifiers"]:
                if qual["Name"] == "mortality":
                    key = 1
    if not key:
        print(pmid)
print("the articles above don't have the qualifier 'Mortality' in database but they indeed are tagged with it on PubMed.")
#         break
# Out:
# 32798029
# 32928549
# 33074524
# 33405353
# 33535932
# 33632637
# 33675715
# 33745714
# 33955021
# 33965332
# 34045062
# 34243724
# 34585490
# 34689572
# 34752418
# 34820983
# the articles above don't have the qualifier 'Mortality' in database but they indeed are tagged with it on PubMed.

# %% [markdown]
# Check if the corresponding abstracts exist in the database, skip them and save the relevant abstracts in text.

# %%
## Extract information and consturct the positive dataset
start = time.time()
conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')
cu = conn.cursor()
statement = "SELECT PMID, Title, Abstract, Keywords from articles  WHERE pmid in ({0})".format(', '.join(['?'] * len(positive)))
article = cu.execute(statement, positive)
i = 0
positive_noabs = []
for row in article:
    s = ""
    pmid = row[0]
    title = row[1]
    abstact = row[2]
    keywords = row[3]
    abstract_dic = ast.literal_eval(abstact)
    
    for subt in abstract_dic:
        s1 = subt["Text"]
        if s1 == None:
            continue
        else:
            if s == "":
                s = s + s1 
            else:
                s = s + " " + s1
        s1 = ""
        
    if s == "":
        print("article without the abstract, the pmid is %s" % pmid)
        positive.remove(pmid)
        positive_noabs.append(pmid) 
        continue        
        
    keywords = keywords.strip("[]")
    text = title + " " + s + " " + keywords
    
    if i<1000:
        p = 'training dataset/positive/%s.txt' % pmid
    elif i<1500:
        p = 'validation dataset/positive/%s.txt' % pmid
    else:
        p = 'test dataset/positive/%s.txt' % pmid
        
#     f=open(p, "w",encoding='utf-8')
#     f.write(text)
#     f.close()
    i += 1
       
print("There are %d positive articles in total" % (i))
conn.close()
end = time.time()
print("Time cost:",end - start)
# Out:
# article without the abstract, the pmid is 28110488
# article without the abstract, the pmid is 30821595
# There are 1746 positive articles in total
# Time cost: 0.21293163299560547

# %% [markdown]
# ### Construct the negative dataset

# %%
## Negative pmid
path = "pmid-HeartTrans-set.txt"
with open(path,'r',encoding='utf-8') as f:
    text = f.read()
negative = text.split("\n")
n = set(negative)
if len(negative) == len(n):
    print("No duplicated PMID in the list.")
else:
    le = len(negative) - len(n)
    print("%d duplicated PMIDs in the list have been removed, and the order in the list was not changed." % le)
    new_list = list(n)
    new_list.sort(key=negative.index)
    negative = new_list
# Out:
# 116 duplicated PMIDs in the list have been removed, and the order in the list was not changed.

# %%
i = 0
for pos in positive:
    if pos in negative:
        negative.remove(pos)
        i += 1
for pos in positive_noabs:
    if pos in negative:
        negative.remove(pos)
        i += 1
print("%d positive articles have been removed from the negative dataset" % i)
print("Now there are %d articles in the negative dataset" % len(negative))
# Out:
# 1748 positive articles have been removed from the negative dataset
# Now there are 15273 articles in the negative dataset

# %%
## Test negative data
conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')
cu = conn.cursor()
statement = "SELECT * from articles  WHERE pmid in ({0})".format(', '.join(['?'] * len(negative)))
article = cu.execute(statement, negative)
i = 0
for row in article:
    s = ""
    pmid = row[0]
    title = row[1]
    abstact = row[2]
    mesh = row[3]
    keywords = row[4]
    mesh_list = ast.literal_eval(mesh)
    key = 0
    for term in mesh_list:
        if term["Name"] in ["Heart Transplantation","Heart-Lung Transplantation"]:
            for qual in term["Qualifiers"]:
                if qual["Name"] == "mortality":
                    key = 1
    if key:
        print("positive article in the negative dataset!!! " + pmid)
    
    key = 0
    for term in mesh_list:
        if term["Name"] in ["Heart Transplantation","Heart-Lung Transplantation"]:
                key = 1  
    if not key:
        if mesh == "[]":
            print("article without mesh term heart_tran " + pmid)
        else:
            print("article error " + pmid)
# Out:
# article without mesh term heart_tran 31891373
# article without mesh term heart_tran 31939750
# article without mesh term heart_tran 31993956
# article without mesh term heart_tran 32354629
# article without mesh term heart_tran 32372168
# article without mesh term heart_tran 32462258
# article without mesh term heart_tran 32572551
# article without mesh term heart_tran 32703639
# article without mesh term heart_tran 32739334
# article without mesh term heart_tran 32768298
# article without mesh term heart_tran 32773322
# article without mesh term heart_tran 32778365
# article without mesh term heart_tran 32841466
# article without mesh term heart_tran 32858640
# article without mesh term heart_tran 32861553
# article without mesh term heart_tran 32870436
# article without mesh term heart_tran 32889634
# article without mesh term heart_tran 32942278
# article without mesh term heart_tran 32950380
# article without mesh term heart_tran 32981709
# article without mesh term heart_tran 33002249
# article without mesh term heart_tran 33012541
# article without mesh term heart_tran 33022372
# article without mesh term heart_tran 33022840
# article without mesh term heart_tran 33055147
# article without mesh term heart_tran 33069814
# article without mesh term heart_tran 33105526
# article without mesh term heart_tran 33112391
# article without mesh term heart_tran 33113077
# article without mesh term heart_tran 33118462
# article without mesh term heart_tran 33124777
# article without mesh term heart_tran 33131128
# article without mesh term heart_tran 33148937
# article without mesh term heart_tran 33150533
# article without mesh term heart_tran 33179426
# article without mesh term heart_tran 33179431
# article without mesh term heart_tran 33185130
# article without mesh term heart_tran 33210224
# article without mesh term heart_tran 33245837
# article without mesh term heart_tran 33257284
# article without mesh term heart_tran 33277170
# article without mesh term heart_tran 33279963
# article without mesh term heart_tran 33280782
# article without mesh term heart_tran 33300457
# article without mesh term heart_tran 33325730
# article without mesh term heart_tran 33326675
# article without mesh term heart_tran 33333620
# article without mesh term heart_tran 33341359
# article without mesh term heart_tran 33361349
# article without mesh term heart_tran 33371825
# article without mesh term heart_tran 33371840
# article without mesh term heart_tran 33389637
# article without mesh term heart_tran 33393702
# article without mesh term heart_tran 33432419
# article without mesh term heart_tran 33432621
# article without mesh term heart_tran 33446916
# article without mesh term heart_tran 33455567
# article without mesh term heart_tran 33455723
# article without mesh term heart_tran 33482711
# article without mesh term heart_tran 33483000
# article without mesh term heart_tran 33485775
# article without mesh term heart_tran 33496557
# article without mesh term heart_tran 33522702
# article without mesh term heart_tran 33529349
# article without mesh term heart_tran 33530844
# article without mesh term heart_tran 33546972
# article without mesh term heart_tran 33563033
# article without mesh term heart_tran 33571164
# article without mesh term heart_tran 33573599
# article without mesh term heart_tran 33577250
# article without mesh term heart_tran 33579597
# article without mesh term heart_tran 33581286
# article without mesh term heart_tran 33592299
# article without mesh term heart_tran 33599850
# article without mesh term heart_tran 33606485
# article without mesh term heart_tran 33610430
# article without mesh term heart_tran 33612360
# article without mesh term heart_tran 33618961
# article without mesh term heart_tran 33629154
# article without mesh term heart_tran 33633041
# article without mesh term heart_tran 33642140
# article without mesh term heart_tran 33648882
# article without mesh term heart_tran 33657374
# article without mesh term heart_tran 33667630
# article without mesh term heart_tran 33704881
# article without mesh term heart_tran 33726889
# article without mesh term heart_tran 33726982
# article without mesh term heart_tran 33737091
# article without mesh term heart_tran 33741785
# article without mesh term heart_tran 33744086
# article without mesh term heart_tran 33744197
# article without mesh term heart_tran 33745782
# article without mesh term heart_tran 33749089
# article without mesh term heart_tran 33755282
# article without mesh term heart_tran 33755723
# article without mesh term heart_tran 33769354
# article without mesh term heart_tran 33785250
# article without mesh term heart_tran 33794163
# article without mesh term heart_tran 33838298
# article without mesh term heart_tran 33839007
# article without mesh term heart_tran 33846079
# article without mesh term heart_tran 33849770
# article without mesh term heart_tran 33851398
# article without mesh term heart_tran 33863685
# article without mesh term heart_tran 33877035
# article without mesh term heart_tran 33879383
# article without mesh term heart_tran 33887578
# article without mesh term heart_tran 33894179
# article without mesh term heart_tran 33903017
# article without mesh term heart_tran 33905863
# article without mesh term heart_tran 33906787
# article without mesh term heart_tran 33909325
# article without mesh term heart_tran 33915443
# article without mesh term heart_tran 33931802
# article without mesh term heart_tran 33947602
# article without mesh term heart_tran 33951698
# article without mesh term heart_tran 33956540
# article without mesh term heart_tran 33971066
# article without mesh term heart_tran 33975012
# article without mesh term heart_tran 33975013
# article without mesh term heart_tran 33978673
# article without mesh term heart_tran 33983835
# article without mesh term heart_tran 33988340
# article without mesh term heart_tran 33994229
# article without mesh term heart_tran 34003559
# article without mesh term heart_tran 34006449
# article without mesh term heart_tran 34052126
# article without mesh term heart_tran 34078559
# article without mesh term heart_tran 34083118
# article without mesh term heart_tran 34092272
# article without mesh term heart_tran 34100537
# article without mesh term heart_tran 34111946
# article without mesh term heart_tran 34112578
# article without mesh term heart_tran 34120386
# article without mesh term heart_tran 34120877
# article without mesh term heart_tran 34126624
# article without mesh term heart_tran 34127356
# article without mesh term heart_tran 34129685
# article without mesh term heart_tran 34134912
# article without mesh term heart_tran 34138489
# article without mesh term heart_tran 34154321
# article without mesh term heart_tran 34157374
# article without mesh term heart_tran 34167863
# article without mesh term heart_tran 34176726
# article without mesh term heart_tran 34181241
# article without mesh term heart_tran 34181771
# article without mesh term heart_tran 34187714
# article without mesh term heart_tran 34212503
# article without mesh term heart_tran 34214903
# article without mesh term heart_tran 34224863
# article without mesh term heart_tran 34228988
# article without mesh term heart_tran 34236044
# article without mesh term heart_tran 34236047
# article without mesh term heart_tran 34236797
# article without mesh term heart_tran 34241930
# article without mesh term heart_tran 34253454
# article without mesh term heart_tran 34253456
# article without mesh term heart_tran 34253457
# article without mesh term heart_tran 34253459
# article without mesh term heart_tran 34254366
# article without mesh term heart_tran 34260889
# article without mesh term heart_tran 34264154
# article without mesh term heart_tran 34265128
# article without mesh term heart_tran 34272125
# article without mesh term heart_tran 34274182
# article without mesh term heart_tran 34274269
# article without mesh term heart_tran 34274515
# article without mesh term heart_tran 34281777
# article without mesh term heart_tran 34283959
# article without mesh term heart_tran 34288107
# article without mesh term heart_tran 34291552
# article without mesh term heart_tran 34296503
# article without mesh term heart_tran 34296798
# article without mesh term heart_tran 34313167
# article without mesh term heart_tran 34314824
# article without mesh term heart_tran 34315226
# article without mesh term heart_tran 34318517
# article without mesh term heart_tran 34319617
# article without mesh term heart_tran 34320235
# article without mesh term heart_tran 34321120
# article without mesh term heart_tran 34325007
# article without mesh term heart_tran 34330603
# article without mesh term heart_tran 34330605
# article without mesh term heart_tran 34330606
# article without mesh term heart_tran 34332861
# article without mesh term heart_tran 34333595
# article without mesh term heart_tran 34334299
# article without mesh term heart_tran 34334301
# article without mesh term heart_tran 34343276
# article without mesh term heart_tran 34352365
# article without mesh term heart_tran 34362644
# article without mesh term heart_tran 34363421
# article without mesh term heart_tran 34365483
# article without mesh term heart_tran 34365682
# article without mesh term heart_tran 34366230
# article without mesh term heart_tran 34375309
# article without mesh term heart_tran 34390091
# article without mesh term heart_tran 34390599
# article without mesh term heart_tran 34398485
# article without mesh term heart_tran 34398487
# article without mesh term heart_tran 34402096
# article without mesh term heart_tran 34402927
# article without mesh term heart_tran 34405495
# article without mesh term heart_tran 34407451
# article without mesh term heart_tran 34409711
# article without mesh term heart_tran 34411345
# article without mesh term heart_tran 34412962
# article without mesh term heart_tran 34414769
# article without mesh term heart_tran 34420244
# article without mesh term heart_tran 34420849
# article without mesh term heart_tran 34420852
# article without mesh term heart_tran 34421916
# article without mesh term heart_tran 34431324
# article without mesh term heart_tran 34435466
# article without mesh term heart_tran 34438097
# article without mesh term heart_tran 34446355
# article without mesh term heart_tran 34447390
# article without mesh term heart_tran 34454287
# article without mesh term heart_tran 34456108
# article without mesh term heart_tran 34461675
# article without mesh term heart_tran 34462628
# article without mesh term heart_tran 34463172
# article without mesh term heart_tran 34465530
# article without mesh term heart_tran 34467613
# article without mesh term heart_tran 34470491
# article without mesh term heart_tran 34474597
# article without mesh term heart_tran 34476863
# article without mesh term heart_tran 34476876
# article without mesh term heart_tran 34482766
# article without mesh term heart_tran 34487311
# article without mesh term heart_tran 34487636
# article without mesh term heart_tran 34490749
# article without mesh term heart_tran 34503344
# article without mesh term heart_tran 34504489
# article without mesh term heart_tran 34509349
# article without mesh term heart_tran 34509597
# article without mesh term heart_tran 34509598
# article without mesh term heart_tran 34510564
# article without mesh term heart_tran 34510802
# article without mesh term heart_tran 34510806
# article without mesh term heart_tran 34511330
# article without mesh term heart_tran 34515371
# article without mesh term heart_tran 34516668
# article without mesh term heart_tran 34519177
# article without mesh term heart_tran 34520113
# article without mesh term heart_tran 34523009
# article without mesh term heart_tran 34523254
# article without mesh term heart_tran 34525116
# article without mesh term heart_tran 34525263
# article without mesh term heart_tran 34525329
# article without mesh term heart_tran 34529289
# article without mesh term heart_tran 34545665
# article without mesh term heart_tran 34546591
# article without mesh term heart_tran 34546613
# article without mesh term heart_tran 34548198
# article without mesh term heart_tran 34551864
# article without mesh term heart_tran 34555935
# article without mesh term heart_tran 34557655
# article without mesh term heart_tran 34562279
# article without mesh term heart_tran 34565682
# article without mesh term heart_tran 34566976
# article without mesh term heart_tran 34580890
# article without mesh term heart_tran 34584108
# article without mesh term heart_tran 34585497
# article without mesh term heart_tran 34597211
# article without mesh term heart_tran 34598871
# article without mesh term heart_tran 34598872
# article without mesh term heart_tran 34600071
# article without mesh term heart_tran 34600147
# article without mesh term heart_tran 34600476
# article without mesh term heart_tran 34608773
# article without mesh term heart_tran 34614256
# article without mesh term heart_tran 34620574
# article without mesh term heart_tran 34633676
# article without mesh term heart_tran 34634150
# article without mesh term heart_tran 34635381
# article without mesh term heart_tran 34644421
# article without mesh term heart_tran 34649160
# article without mesh term heart_tran 34649304
# article without mesh term heart_tran 34651198
# article without mesh term heart_tran 34651943
# article without mesh term heart_tran 34652629
# article without mesh term heart_tran 34657372
# article without mesh term heart_tran 34661328
# article without mesh term heart_tran 34665224
# article without mesh term heart_tran 34666942
# article without mesh term heart_tran 34668614
# article without mesh term heart_tran 34669032
# article without mesh term heart_tran 34669978
# article without mesh term heart_tran 34673300
# article without mesh term heart_tran 34687149
# article without mesh term heart_tran 34687578
# article without mesh term heart_tran 34688547
# article without mesh term heart_tran 34689383
# article without mesh term heart_tran 34698399
# article without mesh term heart_tran 34699976
# article without mesh term heart_tran 34704397
# article without mesh term heart_tran 34709681
# article without mesh term heart_tran 34711747
# article without mesh term heart_tran 34725418
# article without mesh term heart_tran 34727417
# article without mesh term heart_tran 34728077
# article without mesh term heart_tran 34728079
# article without mesh term heart_tran 34730005
# article without mesh term heart_tran 34731013
# article without mesh term heart_tran 34732298
# article without mesh term heart_tran 34734490
# article without mesh term heart_tran 34738731
# article without mesh term heart_tran 34742623
# article without mesh term heart_tran 34742645
# article without mesh term heart_tran 34742866
# article without mesh term heart_tran 34743559
# article without mesh term heart_tran 34747048
# article without mesh term heart_tran 34755387
# article without mesh term heart_tran 34756511
# article without mesh term heart_tran 34756710
# article without mesh term heart_tran 34766385
# article without mesh term heart_tran 34772489
# article without mesh term heart_tran 34777394
# article without mesh term heart_tran 34779321
# article without mesh term heart_tran 34779880
# article without mesh term heart_tran 34782170
# article without mesh term heart_tran 34783215
# article without mesh term heart_tran 34783354
# article without mesh term heart_tran 34801581
# article without mesh term heart_tran 34802875
# article without mesh term heart_tran 34809650
# article without mesh term heart_tran 34815060
# article without mesh term heart_tran 34815161
# article without mesh term heart_tran 34821079
# article without mesh term heart_tran 34825441
# article without mesh term heart_tran 34826752
# article without mesh term heart_tran 34831135
# article without mesh term heart_tran 34836605
# article without mesh term heart_tran 34854252
# article without mesh term heart_tran 34854316
# article without mesh term heart_tran 34860187
# article without mesh term heart_tran 34865973
# article without mesh term heart_tran 34870762
# article without mesh term heart_tran 34875599
# article without mesh term heart_tran 34879140
# article without mesh term heart_tran 34879706
# article without mesh term heart_tran 34881809
# article without mesh term heart_tran 34886963
# article without mesh term heart_tran 34891713
# article without mesh term heart_tran 34893302
# article without mesh term heart_tran 34893663

# %%
## Extract information and consturct the negative dataset
negative_noabs = []
start = time.time()
conn = sqlite3.connect('D:\\PubMed_Sqlite3\\pubmed.db')
cu = conn.cursor()
statement = "SELECT PMID, Title, Abstract, Keywords from articles  WHERE pmid in ({0})".format(', '.join(['?'] * len(negative)))
article = cu.execute(statement, negative)
i = 0
for row in article:
    s = ""
    pmid = row[0]
    title = row[1]
    abstact = row[2]
    keywords = row[3]
    abstract_dic = ast.literal_eval(abstact)
    
    for subt in abstract_dic:
        s1 = subt["Text"]
        if s1 == None:
            continue

        else:
            if s == "":
                s = s + s1 
            else:
                s = s + " " + s1
        s1 = ""
    
    if s == "":
        print("article without the abstract, the pmid is %s" % pmid)
        negative_noabs.append(pmid)
        negative.remove(pmid)
        continue
        
    keywords = keywords.strip("[]")
    try:
        text = title + " " + s + " " + keywords
    except:
        text = s + " " + keywords
    
    if i<1000:
        p = 'training dataset/negative/%s.txt' % pmid
    elif i<1500:
        p = 'validation dataset/negative/%s.txt' % pmid
    else:
        p = 'test dataset/negative/%s.txt' % pmid
        
#     f=open(p, "w",encoding='utf-8')
#     f.write(text)
#     f.close()
    i += 1
       
print("There are %d negative articles in total" % (i+1))
conn.close()
end = time.time()
print("Time cost:",end - start)
# Out:
# article without the abstract, the pmid is 19876441
# article without the abstract, the pmid is 20385962
# article without the abstract, the pmid is 23304053
# article without the abstract, the pmid is 25002571
# article without the abstract, the pmid is 26216213
# article without the abstract, the pmid is 26655937
# article without the abstract, the pmid is 27903010
# article without the abstract, the pmid is 28030875
# article without the abstract, the pmid is 28316176
# article without the abstract, the pmid is 28545281
# article without the abstract, the pmid is 29799959
# article without the abstract, the pmid is 30096261
# article without the abstract, the pmid is 30694075
# article without the abstract, the pmid is 31132883
# article without the abstract, the pmid is 31315301
# article without the abstract, the pmid is 31431128
# article without the abstract, the pmid is 31584336
# article without the abstract, the pmid is 31661343
# article without the abstract, the pmid is 31672395
# article without the abstract, the pmid is 31692381
# article without the abstract, the pmid is 31755847
# article without the abstract, the pmid is 31774339
# article without the abstract, the pmid is 31921152
# article without the abstract, the pmid is 32197268
# article without the abstract, the pmid is 32216552
# article without the abstract, the pmid is 32293645
# article without the abstract, the pmid is 32724457
# article without the abstract, the pmid is 32783558
# article without the abstract, the pmid is 32849549
# article without the abstract, the pmid is 32856335
# article without the abstract, the pmid is 32867905
# article without the abstract, the pmid is 32994096
# article without the abstract, the pmid is 33624522
# article without the abstract, the pmid is 33783039
# article without the abstract, the pmid is 33832025
# article without the abstract, the pmid is 34160345
# There are 15208 negative articles in total
# Time cost: 1.464531660079956
